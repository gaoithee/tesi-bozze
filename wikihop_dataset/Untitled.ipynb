# %%
import pandas as pd

summ = pd.read_csv('wikihop-merged-summarized-test.csv')
summ.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  \
# 0             0             0           0
# 1             1             1           1
# 2             3             3           3
# 3             6             6           6
# 4             7             7           7
#
#                                                query                answer  \
# 0        What event did Juan Rossell participate in?  1996 summer olympics
# 1     What languages did John Osteen speak or write?               english
# 2        What is the parent taxon of Australosuchus?            crocodilia
# 3  What is the'record_label method man' associate...          loud records
# 4  In which administrative territorial entity is ...       raipur district
#
#                                              options  \
# 0  ['1996 summer olympics', 'olympic games', 'spo...
# 1  ['english', 'greek', 'koine greek', 'nahuatl',...
# 2  ['animal', 'area', 'crocodile', 'crocodilia', ...
# ...

# %%
all_rows = pd.read_csv('wikihop-dataset-1000.csv')
all_rows.head()
# Out:
#    Unnamed: 0                                              query  \
# 0           0   Assistant: "What event did Juan Rossell parti...
# 1           1   Assistant: "What languages did John Osteen sp...
# 2           2    "What is the parent taxon of Proaigialosaurus?"
# 3           3   Assistant: "What is the parent taxon of Austr...
# 4           4   "What was the occupation of Cao Chong?"\n\nAs...
#
#                  answer                                            options  \
# 0  1996 summer olympics  ['1996 summer olympics', 'olympic games', 'spo...
# 1               english  ['english', 'greek', 'koine greek', 'nahuatl',...
# 2          lepidosauria  ['alligatoridae', 'amphibia', 'amphisbaenia', ...
# 3            crocodilia  ['animal', 'area', 'crocodile', 'crocodilia', ...
# 4             physicist  ['academic', 'builder', 'chancellor', 'classic...
#
#                                             supports  \
# 0  The 2004 Summer Olympic Games, officially know...
# ...

# %%
merged_df = pd.merge(summ, all_rows, left_on='query', right_on="cleaned_query",merged_df = pd.merge(df1, df2, on='id', how='inner') how='inner')

# %%
merged_df.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0_x  \
# 0             0             0             0
# 1             1             1             1
# 2             3             3             3
# 3             6             6             6
# 4             7             7             7
#
#                                              query_x              answer_x  \
# 0        What event did Juan Rossell participate in?  1996 summer olympics
# 1     What languages did John Osteen speak or write?               english
# 2        What is the parent taxon of Australosuchus?            crocodilia
# 3  What is the'record_label method man' associate...          loud records
# 4  In which administrative territorial entity is ...       raipur district
#
#                                            options_x  \
# 0  ['1996 summer olympics', 'olympic games', 'spo...
# 1  ['english', 'greek', 'koine greek', 'nahuatl',...
# 2  ['animal', 'area', 'crocodile', 'crocodilia', ...
# ...

# %%
merged_df = merged_df.drop(['Unnamed: 0_x', 'Unnamed: 0_y', 'query_y', 'answer_y', 'options_y', 'cleaned_query'], axis=1)

# %%
merged_df.head()
# Out:
#                                              query_x              answer_x  \
# 0        What event did Juan Rossell participate in?  1996 summer olympics
# 1     What languages did John Osteen speak or write?               english
# 2        What is the parent taxon of Australosuchus?            crocodilia
# 3  What is the'record_label method man' associate...          loud records
# 4  In which administrative territorial entity is ...       raipur district
#
#                                            options_x  \
# 0  ['1996 summer olympics', 'olympic games', 'spo...
# 1  ['english', 'greek', 'koine greek', 'nahuatl',...
# 2  ['animal', 'area', 'crocodile', 'crocodilia', ...
# 3  ['1995', '1996', 'album', 'english', 'epic', '...
# 4  ['bangladesh', 'bhopal', 'bhutan', 'canada', '...
#
#                                         sum_supports  \
# 0   The 2004 Summer Olympic Games, held in Athens...
# 1   Christianity is a monotheistic religion based...
# ...

# %%
merged_df.to_csv('test-wikihop.csv')
